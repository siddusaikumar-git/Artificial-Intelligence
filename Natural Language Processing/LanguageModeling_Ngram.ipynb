# %%
import pandas as pd
import numpy as np
import nltk

from nltk.corpus import reuters

nltk.download('reuters')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package reuters to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
reuters.categories()
# Out:
# ['acq',
#  'alum',
#  'barley',
#  'bop',
#  'carcass',
#  'castor-oil',
#  'cocoa',
#  'coconut',
#  'coconut-oil',
#  'coffee',
#  'copper',
#  'copra-cake',
#  'corn',
#  'cotton',
#  'cotton-oil',
#  'cpi',
#  'cpu',
#  'crude',
#  'dfl',
#  'dlr',
#  'dmk',
#  'earn',
#  'fuel',
#  'gas',
#  'gnp',
#  'gold',
#  'grain',
#  'groundnut',
#  'groundnut-oil',
#  'heat',
#  'hog',
#  'housing',
#  'income',
#  'instal-debt',
#  'interest',
#  'ipi',
#  'iron-steel',
#  'jet',
#  'jobs',
#  'l-cattle',
#  'lead',
#  'lei',
#  'lin-oil',
#  'livestock',
#  'lumber',
#  'meal-feed',
#  'money-fx',
#  'money-supply',
#  'naphtha',
#  'nat-gas',
#  'nickel',
#  'nkr',
#  'nzdlr',
#  'oat',
#  'oilseed',
#  'orange',
#  'palladium',
#  'palm-oil',
#  'palmkernel',
#  'pet-chem',
#  'platinum',
#  'potato',
#  'propane',
#  'rand',
#  'rape-oil',
#  'rapeseed',
#  'reserves',
#  'retail',
#  'rice',
#  'rubber',
#  'rye',
#  'ship',
#  'silver',
#  'sorghum',
#  'soy-meal',
#  'soy-oil',
#  'soybean',
#  'strategic-metal',
#  'sugar',
#  'sun-meal',
#  'sun-oil',
#  'sunseed',
#  'tea',
#  'tin',
#  'trade',
#  'veg-oil',
#  'wheat',
#  'wpi',
#  'yen',
#  'zinc']

# %%
for i, sent in enumerate(reuters.sents()[:10]):
  print("sentence ", i, ":", " ".join(sent))
# Out:
# sentence  0 : ASIAN EXPORTERS FEAR DAMAGE FROM U . S .- JAPAN RIFT Mounting trade friction between the U . S . And Japan has raised fears among many of Asia ' s exporting nations that the row could inflict far - reaching economic damage , businessmen and officials said .
# sentence  1 : They told Reuter correspondents in Asian capitals a U . S . Move against Japan might boost protectionist sentiment in the U . S . And lead to curbs on American imports of their products .
# sentence  2 : But some exporters said that while the conflict would hurt them in the long - run , in the short - term Tokyo ' s loss might be their gain .
# sentence  3 : The U . S . Has said it will impose 300 mln dlrs of tariffs on imports of Japanese electronics goods on April 17 , in retaliation for Japan ' s alleged failure to stick to a pact not to sell semiconductors on world markets at below cost .
# sentence  4 : Unofficial Japanese estimates put the impact of the tariffs at 10 billion dlrs and spokesmen for major electronics firms said they would virtually halt exports of products hit by the new taxes .
# sentence  5 : " We wouldn ' t be able to do business ," said a spokesman for leading Japanese electronics firm Matsushita Electric Industrial Co Ltd & lt ; MC . T >.
# sentence  6 : " If the tariffs remain in place for any length of time beyond a few months it will mean the complete erosion of exports ( of goods subject to tariffs ) to the U . S .," said Tom Murtha , a stock analyst at the Tokyo office of broker & lt ; James Capel and Co >.
# sentence  7 : In Taiwan , businessmen and officials are also worried .
# sentence  8 : " We are aware of the seriousness of the U . S .
# sentence  9 : Threat against Japan because it serves as a warning to us ," said a senior Taiwanese trade official who asked not to be named .

# %%
from collections import Counter, defaultdict
from nltk import trigrams

model = defaultdict(lambda : defaultdict(lambda: 0))

for i, sent in enumerate(reuters.sents()):
  for w1, w2, w3 in trigrams(sent):
    model[(w1, w2)][w3] += 1

# %%
model
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {('ASIAN',
#               'EXPORTERS'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'FEAR': 1}),
#              ('EXPORTERS',
#               'FEAR'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'DAMAGE': 1}),
#              ('FEAR',
#               'DAMAGE'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'FROM': 1}),
#              ('DAMAGE',
#               'FROM'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'U': 1,
#                           'SPILL': 1}),
#              ('FROM',
#               'U'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'.': 4}),
#              ('U',
#               '.'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'S': 5693,
#                           'K': 624,
#                           'N': 28,
#                           'F': 2}),
#              ('.',
#               'S'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'.-': 120,
#                           '.': 5340,
#                           '.,"': 11,
#                           '.,': 155,
#                           '>': 78,
#                           '>,': 7,
#                           '..': 5,
#                           'where': 1,
#                           '.)': 15,
#                           '>-': 4,
#                           'courier': 1,
#                           'Customs': 1,
#                           '.).': 2,
#                           '.),': 1,
#                           'consumer': 1,
#                           '>.': 6,
#                           ',': 7,
#                           ".'": 4,
#                           'TRADE': 1,
#                           '."': 1,
#                           './': 19,
#                           'domestic': 1,
#                           'COMMERCE': 1,
#                           'SENATE': 1,
#                           'ANGER': 1,
#                           '-': 1,
#                           'agriculture': 1,
#                           'and': 1,
#                           'grains': 1,
#                           'SAYS': 1,
#                           'Agriculture': 1,
#                           'in': 2,
#                           'to': 1,
#                           'economy': 1,
#                           'responded': 2,
#                           'OIL': 1,
#                           'dlrs': 1,
#                           'corn': 1,
#                           'ENERGY': 1,
#                           'warship': 2,
#                           '>/': 1,
#                           'later': 1,
#                           '/': 2,
#                           '.>': 1,
#                           'sugar': 1,
#                           'TREASURY': 1}),
#              ('S',
#               '.-'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'JAPAN': 8,
#                           'Japanese': 20,
#                           'based': 5,
#                           'dlr': 2,
#                           'USSR': 13,
#                           'Japan': 14,
#                           'China': 2,
#                           'owned': 3,
#                           'CANADA': 1,
#                           'Canadian': 4,
#                           'European': 2,
#                           'IRAN': 1,
#                           'flag': 2,
#                           'flagged': 12,
#                           'West': 3,
#                           'WEST': 1,
#                           'protected': 1,
#                           'Israeli': 1,
#                           'German': 1,
#                           'GERMAN': 2,
#                           'made': 4,
#                           'South': 1,
#                           'Greek': 1,
#                           'EC': 1,
#                           'Soviet': 3,
#                           'Canada': 2,
#                           'origin': 2,
#                           'produced': 3,
#                           'SOVIET': 1,
#                           'British': 2,
#                           'U': 2}),
#              ('.-',
#               'JAPAN'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'RIFT': 1,
#                           'AGREEMENT': 1,
#                           'TRADE': 4,
#                           'NOT': 1,
#                           'MICROCHIP': 1}),
#              ('JAPAN',
#               'RIFT'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'Mounting': 1}),
#              ('RIFT',
#               'Mounting'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'trade': 1}),
#              ('Mounting',
#               'trade'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'friction': 1}),
#              ('trade',
#               'friction'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'between': 3,
#                           'with': 1,
#                           'diplomacy': 1,
#                           '.': 2,
#                           'and': 5,
#                           'unless': 1,
#                           'flared': 1,
#                           'could': 1,
#                           'will': 1,
#                           'is': 1}),
#              ('friction',
#               'between'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'the': 4}),
#              ('between',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'U': 21,
#                           'start': 2,
#                           'two': 85,
#                           'employers': 2,
#                           'United': 16,
#                           'demands': 1,
#                           'countries': 1,
#                           'EC': 6,
#                           'dollar': 2,
#                           'White': 1,
#                           'prime': 4,
#                           'report': 2,
#                           'increased': 1,
#                           'secured': 1,
#                           'pork': 1,
#                           'Omani': 1,
#                           'Group': 3,
#                           'purchase': 1,
#                           'Federal': 1,
#                           'first': 1,
#                           'heaviest': 1,
#                           'growth': 1,
#                           'factories': 1,
#                           'old': 2,
#                           'European': 2,
#                           'prices': 1,
#                           'government': 2,
#                           'Canadian': 1,
#                           'seven': 2,
#                           'study': 1,
#                           'ebullient': 1,
#                           'Bundesbank': 1,
#                           'guilder': 2,
#                           'origins': 1,
#                           '(': 1,
#                           'candidates': 1,
#                           'declaration': 1,
#                           'central': 1,
#                           'Cenepa': 2,
#                           'Japanese': 1,
#                           'Wilkinson': 1,
#                           'parties': 2,
#                           'total': 1,
#                           '15': 1,
#                           'acceptance': 1,
#                           'bank': 1,
#                           'Bank': 1,
#                           'companies': 2,
#                           'pressures': 1,
#                           '3': 1,
#                           '2': 1,
#                           'Fed': 1,
#                           'big': 2,
#                           'Finance': 1,
#                           'ministry': 1,
#                           'beginning': 1,
#                           'company': 1,
#                           'use': 1,
#                           'Dutch': 1,
#                           'latest': 1,
#                           'fall': 1,
#                           'union': 2,
#                           'leading': 1,
#                           'five': 1,
#                           'Philippines': 1,
#                           'six': 2,
#                           'world': 3,
#                           'coast': 1,
#                           'end': 1,
#                           'Indian': 1,
#                           'loan': 1,
#                           'parent': 1,
#                           'Community': 2,
#                           '&': 1,
#                           'premium': 1,
#                           'copper': 1,
#                           'British': 1,
#                           'second': 1,
#                           'utility': 1,
#                           'large': 2,
#                           'New': 1,
#                           'major': 1,
#                           'producers': 1,
#                           'Ugandan': 1,
#                           'federal': 1,
#                           'volume': 1,
#                           'Commission': 2,
#                           'commercial': 1}),
#              ('the',
#               'U'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'.': 1959}),
#              ('S',
#               '.'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'And': 135,
#                           'Move': 1,
#                           'Has': 21,
#                           'Products': 3,
#                           'Pressure': 7,
#                           'Last': 5,
#                           'Exports': 10,
#                           'Trade': 103,
#                           'Department': 35,
#                           'Dlrs': 108,
#                           'Securities': 9,
#                           'Glass': 1,
#                           'Commercial': 2,
#                           'Japan': 2,
#                           'Officials': 60,
#                           'Farm': 5,
#                           'Would': 19,
#                           'To': 16,
#                           'Agriculture': 250,
#                           'Market': 19,
#                           'Corn': 4,
#                           'Will': 9,
#                           'Feedgrain': 1,
#                           'Limit': 1,
#                           'Currency': 35,
#                           'SANCTIONS': 2,
#                           'Official': 7,
#                           'Not': 6,
#                           'Hopes': 2,
#                           'Investors': 3,
#                           'Dollar': 56,
#                           'Unit': 8,
#                           'Where': 1,
#                           'Charges': 3,
#                           'Decision': 2,
#                           'Chip': 3,
#                           'to': 15,
#                           'Concern': 7,
#                           'Complaint': 3,
#                           'banking': 7,
#                           'C': 9,
#                           'Treasury': 88,
#                           'dollar': 37,
#                           'petrochemical': 3,
#                           'chemical': 4,
#                           'economy': 31,
#                           'textile': 7,
#                           'investor': 1,
#                           'defense': 5,
#                           'Government': 44,
#                           'no': 3,
#                           'A': 65,
#                           'parent': 5,
#                           'acquisition': 2,
#                           'tariffs': 3,
#                           'semiconductor': 7,
#                           'and': 76,
#                           'officials': 52,
#                           'trade': 95,
#                           'firms': 8,
#                           'PURCHASE': 2,
#                           'Medical': 4,
#                           'Subsidiary': 4,
#                           'GOVERNMENT': 5,
#                           'FARM': 8,
#                           'lawmakers': 5,
#                           'dairy': 1,
#                           'interest': 10,
#                           'Engineering': 1,
#                           'Tariffs': 6,
#                           'reserves': 3,
#                           'producers': 6,
#                           'MEAT': 5,
#                           'meat': 11,
#                           'broilers': 1,
#                           'AGriculture': 1,
#                           'wheat': 48,
#                           'ports': 5,
#                           'corn': 74,
#                           'prices': 4,
#                           'market': 17,
#                           'INTEREST': 2,
#                           'economic': 11,
#                           'probably': 1,
#                           'over': 4,
#                           'steel': 1,
#                           'have': 5,
#                           'SENATE': 14,
#                           'OIL': 18,
#                           'oil': 43,
#                           'government': 43,
#                           'consumption': 8,
#                           'Current': 5,
#                           'Imports': 6,
#                           'At': 4,
#                           'That': 4,
#                           'Firms': 20,
#                           'OUTPUT': 1,
#                           'DLRS': 3,
#                           'Dlr': 9,
#                           'February': 3,
#                           'Insurer': 1,
#                           'sanctions': 2,
#                           '"': 19,
#                           'FIRST': 6,
#                           'FUNDS': 1,
#                           'funds': 5,
#                           'ENERGY': 10,
#                           'energy': 6,
#                           'B': 2,
#                           'Gulf': 12,
#                           'SAID': 3,
#                           'commitment': 2,
#                           'unit': 4,
#                           'Company': 5,
#                           'Buying': 1,
#                           'LEAD': 3,
#                           'courier': 11,
#                           'subsidiary': 11,
#                           'TRADERS': 2,
#                           'Ackerman': 1,
#                           'TREASURY': 17,
#                           'Congress': 26,
#                           'remained': 1,
#                           'tobacco': 1,
#                           'MARCH': 2,
#                           'retailers': 2,
#                           'soyoil': 1,
#                           'sugar': 12,
#                           'Defense': 10,
#                           'cts': 7,
#                           'outlook': 1,
#                           '1986': 2,
#                           'ORANGE': 2,
#                           'SUPPLY': 3,
#                           'CITRUS': 1,
#                           'orange': 1,
#                           'CORN': 28,
#                           '(': 3,
#                           'exporters': 16,
#                           'Bankruptcy': 7,
#                           'may': 3,
#                           'depended': 1,
#                           'than': 1,
#                           'dependency': 1,
#                           'hatching': 1,
#                           'protein': 3,
#                           'WEEKLY': 2,
#                           'soybean': 19,
#                           'D': 2,
#                           '19': 1,
#                           'quality': 2,
#                           'producing': 3,
#                           'Spot': 1,
#                           'M': 22,
#                           'DISCOUNT': 2,
#                           'BANK': 22,
#                           'bank': 14,
#                           'MONEY': 5,
#                           'Crude': 1,
#                           'last': 1,
#                           'relected': 1,
#                           'West': 4,
#                           'DOLLAR': 1,
#                           'Federal': 20,
#                           'commodities': 2,
#                           'dlrs': 54,
#                           'G': 5,
#                           'MARKETS': 1,
#                           'Financial': 4,
#                           'Budget': 4,
#                           'Is': 18,
#                           'Calls': 2,
#                           'Machinery': 2,
#                           'GREEN': 3,
#                           'roastings': 3,
#                           'UNIT': 1,
#                           'RICHARDS': 1,
#                           'Companies': 6,
#                           'RATE': 1,
#                           'Interest': 11,
#                           'Monetary': 4,
#                           'Oil': 11,
#                           'Industry': 10,
#                           '27': 1,
#                           'ATLANTIC': 1,
#                           'Gordon': 1,
#                           'FEEDER': 1,
#                           'Feeder': 1,
#                           'BANCORP': 3,
#                           'employees': 1,
#                           'Trust': 3,
#                           'by': 5,
#                           'underwriters': 1,
#                           'revenues': 1,
#                           'On': 8,
#                           'TRUST': 4,
#                           'SETS': 2,
#                           'FEBRUARY': 5,
#                           'Sprint': 4,
#                           'GAS': 1,
#                           'competitors': 1,
#                           'plants': 4,
#                           'cattle': 1,
#                           'BANKS': 3,
#                           'banks': 24,
#                           'inflation': 2,
#                           'currency': 13,
#                           'discount': 1,
#                           'East': 1,
#                           'dlr': 16,
#                           'rice': 6,
#                           'agricultural': 17,
#                           'TRADE': 30,
#                           'AGENCY': 4,
#                           'International': 6,
#                           'supply': 1,
#                           'bankrupcty': 1,
#                           'Supreme': 6,
#                           'BILL': 4,
#                           'bankruptcy': 4,
#                           'Sugar': 2,
#                           'SOYBEANS': 9,
#                           'Commerce': 15,
#                           'URGES': 5,
#                           'Rose': 6,
#                           'Rice': 2,
#                           'Cattle': 1,
#                           'Proposal': 1,
#                           'Foodgrains': 1,
#                           'Reprisals': 1,
#                           'Goods': 3,
#                           'Rules': 1,
#                           'Support': 1,
#                           'products': 11,
#                           'retaliation': 3,
#                           'central': 4,
#                           'exports': 18,
#                           'COMMERCE': 8,
#                           'MONETARY': 2,
#                           'BUSINESS': 16,
#                           'trading': 8,
#                           'farm': 14,
#                           'TARIFFS': 1,
#                           'arm': 3,
#                           'Gnp': 1,
#                           'South': 2,
#                           'Had': 10,
#                           'STUDY': 1,
#                           'Economy': 18,
#                           'Industrial': 1,
#                           'Industries': 1,
#                           'Economic': 9,
#                           'manufacturing': 3,
#                           'district': 1,
#                           'GULF': 1,
#                           'RIG': 2,
#                           'drilling': 7,
#                           'countervailing': 1,
#                           'or': 4,
#                           'forest': 1,
#                           'system': 1,
#                           'in': 9,
#                           'lumbermen': 1,
#                           'lumber': 4,
#                           'Justice': 7,
#                           'publishing': 1,
#                           'District': 13,
#                           'VIDEO': 1,
#                           'Video': 3,
#                           'frigate': 3,
#                           'Bancorp': 5,
#                           'Thrift': 1,
#                           'UNPREPARED': 1,
#                           'participation': 2,
#                           'military': 12,
#                           'action': 7,
#                           'Geneen': 1,
#                           'Court': 7,
#                           'be': 1,
#                           'goods': 22,
#                           'monetary': 2,
#                           'calls': 1,
#                           'Hart': 2,
#                           'Did': 3,
#                           'Senate': 19,
#                           'COMPANY': 3,
#                           'Firm': 8,
#                           'Sectors': 1,
#                           'Investment': 4,
#                           'AFRICA': 6,
#                           'Should': 4,
#                           'GOLD': 5,
#                           'salmonellosis': 1,
#                           'HOUSE': 23,
#                           'WEIGHS': 1,
#                           'domestic': 4,
#                           'financial': 3,
#                           'analysts': 1,
#                           'stocks': 4,
#                           'Energy': 4,
#                           'Secretary': 11,
#                           'Might': 1,
#                           'Could': 3,
#                           'FEED': 2,
#                           'crude': 9,
#                           'flag': 16,
#                           'TO': 9,
#                           'arms': 2,
#                           'warships': 10,
#                           'Holding': 2,
#                           'where': 1,
#                           'barley': 6,
#                           'flags': 2,
#                           'forces': 11,
#                           'wood': 3,
#                           'APRIL': 1,
#                           'could': 5,
#                           'production': 7,
#                           'RESERVE': 1,
#                           'reserve': 2,
#                           'House': 9,
#                           'policy': 5,
#                           'upgraded': 1,
#                           'copper': 2,
#                           'warship': 1,
#                           'plan': 3,
#                           'During': 2,
#                           'beef': 6,
#                           'Meat': 5,
#                           'imports': 6,
#                           'pressure': 2,
#                           'tenderloin': 1,
#                           'striploin': 1,
#                           'into': 1,
#                           'budget': 7,
#                           'KOREAN': 3,
#                           'Policy': 5,
#                           'Deficit': 5,
#                           'KOREA': 7,
#                           'AFRICAN': 13,
#                           'Soybeans': 7,
#                           'Health': 1,
#                           'personal': 3,
#                           'AND': 4,
#                           'THRIFT': 2,
#                           'League': 4,
#                           'benchmark': 11,
#                           'STEEL': 2,
#                           'cent': 2,
#                           'Superfund': 1,
#                           'Was': 11,
#                           'Chamber': 3,
#                           'Technology': 3,
#                           'CONSUMER': 7,
#                           'is': 13,
#                           'consumer': 5,
#                           'growth': 2,
#                           'farmers': 6,
#                           'would': 8,
#                           'put': 1,
#                           'BUDGET': 5,
#                           'Banking': 1,
#                           'Housing': 1,
#                           'For': 7,
#                           'CHIP': 1,
#                           'Shaw': 1,
#                           'Failed': 1,
#                           'Groundnut': 1,
#                           'Up': 1,
#                           'COURT': 2,
#                           'REFUSES': 1,
#                           'allowable': 1,
#                           'primary': 2,
#                           'letter': 1,
#                           'has': 10,
#                           'TANKERS': 1,
#                           'tankers': 1,
#                           'Navy': 19,
#                           'SEC': 1,
#                           'securities': 9,
#                           'corporate': 1,
#                           'ASKS': 2,
#                           'tariff': 1,
#                           'assets': 2,
#                           'FERC': 1,
#                           'ECONOMY': 2,
#                           'debt': 2,
#                           'Consumer': 2,
#                           'Stockbuilding': 1,
#                           'Trading': 2,
#                           'U': 2,
#                           'Assistant': 2,
#                           'Citrus': 1,
#                           'As': 2,
#                           'Inflation': 3,
#                           'pasta': 1,
#                           'moves': 3,
#                           'plans': 1,
#                           'says': 1,
#                           'strike': 3,
#                           'itself': 1,
#                           'WESTERN': 1,
#                           'Edward': 1,
#                           'CONGRESSMAN': 1,
#                           'ships': 2,
#                           'MINERALS': 1,
#                           'Minerals': 4,
#                           'corporations': 1,
#                           'withholding': 1,
#                           'issuers': 1,
#                           '&': 2,
#                           'aluminum': 1,
#                           'Leasing': 1,
#                           'Lomas': 1,
#                           'MAY': 4,
#                           'REASSERTS': 1,
#                           'Plans': 3,
#                           'Israel': 1,
#                           'can': 3,
#                           'were': 3,
#                           'rose': 3,
#                           'grain': 20,
#                           'companies': 18,
#                           'Equities': 2,
#                           'Shares': 1,
#                           'Bonds': 8,
#                           'Institutional': 1,
#                           'Stock': 2,
#                           'Stocks': 1,
#                           'Military': 5,
#                           'LABELLING': 1,
#                           'Over': 5,
#                           'SEPT': 2,
#                           'HOUSING': 7,
#                           'housing': 4,
#                           'Claims': 1,
#                           'COFFEE': 1,
#                           'coffee': 2,
#                           'Customs': 2,
#                           'roaster': 2,
#                           'falsely': 1,
#                           'With': 2,
#                           'Fed': 1,
#                           'TELECOMMUNICATIONS': 1,
#                           'Raids': 2,
#                           'Action': 11,
#                           'negotiator': 1,
#                           'SHOULD': 4,
#                           '-': 1,
#                           'stance': 1,
#                           'demand': 7,
#                           'demands': 2,
#                           'TAKES': 1,
#                           'claims': 1,
#                           'also': 1,
#                           'wants': 3,
#                           'sought': 1,
#                           'flagged': 1,
#                           'guided': 1,
#                           'p': 1,
#                           'operation': 1,
#                           'Virgin': 3,
#                           'naval': 2,
#                           'OFFICIALS': 3,
#                           'official': 11,
#                           'attack': 4,
#                           'diplomatic': 1,
#                           'diplomats': 1,
#                           'analyst': 1,
#                           'recovery': 1,
#                           'resolve': 1,
#                           'retaliatory': 1,
#                           'involvement': 1,
#                           'free': 1,
#                           'pact': 1,
#                           'promising': 1,
#                           'anger': 1,
#                           'HAD': 1,
#                           'grades': 1,
#                           'MILITARY': 1,
#                           'Joint': 1,
#                           'destroyers': 2,
#                           'PLAN': 1,
#                           'Manufacturers': 2,
#                           'STRIKE': 2,
#                           'Destroyers': 2,
#                           'helicopters': 2,
#                           'diplomat': 1,
#                           'intervention': 3,
#                           'Defence': 8,
#                           'administration': 1,
#                           'Relations': 1,
#                           'destruction': 1,
#                           'reaction': 1,
#                           'should': 6,
#                           'must': 1,
#                           'media': 2,
#                           'National': 5,
#                           'source': 1,
#                           'shelved': 1,
#                           'sources': 2,
#                           'earlier': 2,
#                           'Strike': 3,
#                           'Or': 7,
#                           'Said': 3,
#                           'food': 3,
#                           'businesses': 1,
#                           'INDUSTRIAL': 4,
#                           'division': 1,
#                           'Television': 4,
#                           'antitrust': 2,
#                           'consumere': 1,
#                           'foodservice': 1,
#                           'HAS': 2,
#                           'television': 1,
#                           'response': 2,
#                           'shi': 1,
#                           'AGAINST': 1,
#                           'No': 3,
#                           'August': 1,
#                           'COTTON': 4,
#                           'cotton': 5,
#                           'Census': 2,
#                           'operations': 5,
#                           'will': 4,
#                           'HOME': 3,
#                           'Home': 3,
#                           'COMMERCIAL': 8,
#                           'Household': 1,
#                           'semiconductors': 3,
#                           'China': 2,
#                           'Embassy': 20,
#                           'Out': 2,
#                           'reliance': 9,
#                           'cities': 2,
#                           'intelligence': 1,
#                           'experts': 1,
#                           'ON': 2,
#                           'Semiconductors': 4,
#                           'FOR': 3,
#                           'Lines': 13,
#                           'DLR': 1,
#                           'ANGER': 1,
#                           'Opposition': 1,
#                           'MAIZE': 3,
#                           'Against': 1,
#                           'Anger': 4,
#                           'President': 3,
#                           'African': 2,
#                           'Porsche': 1,
#                           'Prices': 1,
#                           'spot': 2,
#                           'location': 1,
#                           'Accounting': 2,
#                           'governement': 1,
#                           'dealers': 2,
#                           'PL': 1,
#                           'number': 6,
#                           'dollars': 6,
#                           'markets': 7,
#                           'PRICE': 1,
#                           'Group': 4,
#                           'HARD': 2,
#                           'LINES': 2,
#                           'REAL': 6,
#                           'workers': 2,
#                           'BANKER': 2,
#                           'Banker': 4,
#                           'Sanctions': 3,
#                           'From': 3,
#                           'Of': 2,
#                           'Chips': 2,
#                           'SEES': 2,
#                           'Expects': 1,
#                           'Access': 1,
#                           'Markets': 5,
#                           'Alleges': 1,
#                           'Bank': 9,
#                           'EST': 2,
#                           'of': 4,
#                           'chips': 1,
#                           'allegations': 1,
#                           'APPEARS': 1,
#                           'strategy': 3,
#                           'deficits': 1,
#                           'Production': 1,
#                           'BASE': 4,
#                           '7': 1,
#                           'Treasuries': 2,
#                           'legislation': 2,
#                           'delegation': 2,
#                           'still': 1,
#                           'remains': 2,
#                           'CONGRESS': 3,
#                           'industries': 5,
#                           'CORPORATE': 1,
#                           'issues': 1,
#                           'refiners': 3,
#                           'refining': 1,
#                           'refineries': 2,
#                           'SUGAR': 5,
#                           'negotiations': 1,
#                           'auto': 4,
#                           'real': 2,
#                           'bonds': 2,
#                           'cattlemen': 1,
#                           'airline': 1,
#                           'CREDIT': 6,
#                           'credit': 1,
#                           'accounting': 1,
#                           'interests': 2,
#                           'Tempers': 1,
#                           'Operating': 2,
#                           'Dispute': 1,
#                           'Requests': 1,
#                           'Doubts': 1,
#                           'Withdrawal': 1,
#                           'represented': 1,
#                           'Transatlantic': 1,
#                           'Computer': 2,
#                           'Senior': 1,
#                           'index': 2,
#                           'SUGARBEET': 1,
#                           'beet': 1,
#                           'sugarbeet': 3,
#                           'based': 2,
#                           'STOCK': 1,
#                           'decision': 1,
#                           'on': 2,
#                           'embassy': 1,
#                           'VISIT': 1,
#                           'REMAINS': 2,
#                           'competitiveness': 7,
#                           'ASIAN': 2,
#                           'proposal': 2,
#                           'initiative': 1,
#                           'missiles': 1,
#                           'DISTILLATE': 2,
#                           'Increases': 1,
#                           'WEATHER': 2,
#                           'multilateral': 1,
#                           'R': 1,
#                           'Japanese': 1,
#                           'OFFICIAL': 3,
#                           'EEP': 2,
#                           'vessels': 4,
#                           '1987': 7,
#                           '87': 2,
#                           'trustee': 2,
#                           'dry': 1,
#                           'cost': 2,
#                           'vegetable': 3,
#                           'specialty': 1,
#                           'origin': 2,
#                           'leading': 1,
#                           'PRIME': 1,
#                           'bond': 1,
#                           'FED': 1,
#                           'Appeals': 1,
#                           'Allis': 4,
#                           'General': 2,
#                           'Appears': 1,
#                           'Strategic': 1,
#                           'Banks': 6,
#                           'ALLIS': 2,
#                           'COPPER': 1,
#                           'rod': 1,
#                           'SUPREME': 3,
#                           'farms': 1,
#                           'factories': 2,
#                           'TALLOW': 1,
#                           'factory': 3,
#                           'LARD': 1,
#                           'case': 1,
#                           'crushing': 1,
#                           'complaint': 1,
#                           'sales': 3,
#                           'housewives': 1,
#                           'money': 3,
#                           'congressmen': 2,
#                           'package': 1,
#                           'roasters': 1,
#                           'POULTRY': 1,
#                           'base': 1,
#                           'industry': 9,
#                           'Commodity': 3,
#                           'Grains': 3,
#                           'DEBT': 2,
#                           'quotas': 1,
#                           'primarily': 1,
#                           'feedgrains': 2,
#                           'outbreak': 1,
#                           'Environmental': 2,
#                           'Prime': 2,
#                           'Food': 7,
#                           'restrictions': 1,
#                           'negotiating': 1,
#                           'soft': 3,
#                           'P': 1,
#                           'each': 1,
#                           'civilian': 2,
#                           'charges': 1,
#                           'bid': 1,
#                           'North': 1,
#                           'Kresge': 1,
#                           'retail': 5,
#                           'stores': 1,
#                           'JOBS': 2,
#                           'March': 2,
#                           'gross': 3,
#                           'GNP': 3,
#                           'SCIENTISTS': 1,
#                           'scientists': 2,
#                           'Chemical': 1,
#                           'DURUM': 1,
#                           'durum': 4,
#                           'mine': 2,
#                           'SILVER': 1,
#                           'RICE': 1,
#                           'share': 2,
#                           'soybeans': 5,
#                           'hard': 2,
#                           'NAVY': 1,
#                           'Intelligence': 2,
#                           'Carriers': 1,
#                           'PURCHASING': 1,
#                           'industrial': 5,
#                           'Purchasing': 1,
#                           'Escorts': 2,
#                           'WINE': 1,
#                           'Council': 1,
#                           'considers': 1,
#                           'mints': 1,
#                           'offer': 6,
#                           'CALLS': 1,
#                           'Deputy': 1,
#                           'sorghum': 2,
#                           'pork': 1,
#                           'electronics': 1,
#                           'was': 7,
#                           'computer': 2,
#                           'chip': 2,
#                           'thinks': 1,
#                           'SAYS': 6,
#                           'had': 3,
#                           'MINT': 2,
#                           'Mint': 5,
#                           'certificate': 1,
#                           'CERTIFIED': 1,
#                           'IMMIGRATION': 1,
#                           'poultry': 1,
#                           'FEB': 9,
#                           'Bushnell': 1,
#                           'counterparts': 1,
#                           'legislators': 1,
#                           'ran': 1,
#                           'urgings': 1,
#                           '10': 2,
#                           'concern': 2,
#                           'company': 3,
#                           'effort': 2,
#                           'Regulatory': 2,
#                           'Air': 3,
#                           'Failure': 1,
#                           'customs': 1,
#                           'State': 6,
#                           'position': 2,
#                           'allies': 2,
#                           'SEEN': 1,
#                           'Producers': 2,
#                           'car': 2,
#                           'attitude': 1,
#                           'recommendations': 1,
#                           'commodity': 1,
#                           'livestock': 1,
#                           'assistant': 1,
#                           'TIED': 1,
#                           'PROTECTIONISM': 1,
#                           'cooperation': 1,
#                           'tactic': 1,
#                           'part': 1,
#                           'business': 2,
#                           'REAFFIRMS': 1,
#                           'might': 2,
#                           'subsidiaries': 2,
#                           'Taiwan': 2,
#                           'TELLS': 1,
#                           'processors': 1,
#                           'Price': 1,
#                           'Telecommunications': 1,
#                           'deficit': 1,
#                           'legislative': 1,
#                           'FIRM': 2,
#                           'Acquisition': 1,
#                           'EARNINGS': 1,
#                           'Fell': 1,
#                           'Sector': 1,
#                           'Earnings': 1,
#                           'Exploration': 1,
#                           'OKAYS': 1,
#                           'RETAIL': 5,
#                           'agencies': 1,
#                           'federal': 1,
#                           'GATT': 1,
#                           'waiver': 1,
#                           'barriers': 1,
#                           'ambassador': 1,
#                           'POLYETHYLENE': 1,
#                           'customers': 1,
#                           'growers': 1,
#                           'recognises': 1,
#                           'marketing': 1,
#                           'congress': 1,
#                           'law': 2,
#                           'Interstate': 3,
#                           'crop': 1,
#                           'clients': 1,
#                           'subsidies': 2,
#                           'employment': 3,
#                           'non': 1,
#                           'durable': 1,
#                           'merchandise': 3,
#                           'POLICY': 3,
#                           'Taft': 2,
#                           'property': 1,
#                           'made': 1,
#                           'eep': 1,
#                           'believes': 2,
#                           'Initiative': 1,
#                           'FEEDGRAINS': 1,
#                           'Feedgrains': 1,
#                           'are': 3,
#                           'FEEDGRAIN': 1,
#                           'futures': 1,
#                           'cents': 5,
#                           'processing': 2,
#                           'ban': 2,
#                           'FACILITIES': 1,
#                           'Facilities': 1,
#                           'for': 4,
#                           'Fsical': 1,
#                           'Agreement': 1,
#                           'Fiscal': 2,
#                           'export': 4,
#                           'RULING': 1,
#                           'PROPERTY': 1,
#                           'properties': 1,
#                           'INSURANCE': 1,
#                           'Insurance': 1,
#                           'Transportation': 1,
#                           'Travers': 2,
#                           'ct': 1,
#                           'GOODS': 2,
#                           'ZINC': 1,
#                           'slab': 1,
#                           'ECONOMIC': 2,
#                           'exceeded': 1,
#                           'productivity': 1,
#                           'An': 1,
#                           'PAYMENTS': 1,
#                           'current': 2,
#                           'WALLCOVERINGS': 1,
#                           'Business': 1,
#                           'dependence': 4,
#                           'SELLS': 2,
#                           'tax': 4,
#                           'INTERVENED': 3,
#                           'SET': 1,
#                           'Administration': 7,
#                           'authorities': 1,
#                           'bought': 1,
#                           'Consortium': 1,
#                           'Semiconductor': 4,
#                           'Have': 5,
#                           'Bean': 1,
#                           'JOINT': 1,
#                           'Are': 2,
#                           'Pension': 1,
#                           'Debt': 2,
#                           'loan': 4,
#                           'May': 2,
#                           'airlines': 2,
#                           'citizens': 2,
#                           '4TH': 2,
#                           'Subsidiaries': 1,
#                           'increased': 2,
#                           'Retail': 3,
#                           'HOSUING': 1,
#                           'Completions': 2,
#                           'JUSTICE': 1,
#                           'rivals': 1,
#                           'institutional': 1,
#                           'Herold': 1,
#                           'brokerage': 4,
#                           'relations': 1,
#                           'DUTY': 1,
#                           'purchases': 1,
#                           'that': 1,
#                           'CONSERVATION': 4,
#                           'plays': 1,
#                           'govt': 1,
#                           'natural': 1,
#                           'Automaker': 1,
#                           'Wine': 1,
#                           'Makers': 1,
#                           'Increase': 1,
#                           'Cotton': 1,
#                           'Lawyer': 1,
#                           'Hit': 3,
#                           'supercomputer': 1,
#                           'manufacturers': 3,
#                           'HEALTH': 1,
#                           'Silas': 1,
#                           'said': 1,
#                           'price': 1,
#                           'SEISMIC': 1,
#                           'exporter': 1,
#                           'M1': 2,
#                           'MARKET': 1,
#                           'actions': 1,
#                           'Real': 1,
#                           'Supercomputer': 3,
#                           'PRODUCER': 5,
#                           'Producer': 1,
#                           'agriculture': 3,
#                           'edition': 1,
#                           'editiion': 1,
#                           'REPORT': 1,
#                           'MAKES': 1,
#                           'producer': 1,
#                           'Inc': 1,
#                           'net': 1,
#                           'DESIGN': 1,
#                           'Design': 4,
#                           'yesterday': 1,
#                           'states': 2,
#                           'cable': 1,
#                           'agreed': 3,
#                           'BHP': 1,
#                           'Foreign': 1,
#                           'Money': 3,
#                           'amounted': 1,
#                           'DROP': 1,
#                           'enforcement': 4,
#                           'SOY': 1,
#                           'Based': 1,
#                           'INTERNATIONAL': 1,
#                           'acreage': 2,
#                           'savings': 1,
#                           'CAPACITY': 1,
#                           'COULD': 1,
#                           'options': 1,
#                           'traders': 1,
#                           'concerning': 1,
#                           'CityFed': 1,
#                           'chipmakers': 1,
#                           'complaints': 2,
#                           'DECLINES': 1,
#                           'K': 1,
#                           'counterpart': 1,
#                           'Wyatt': 1,
#                           'Steps': 2,
#                           'Moves': 4,
#                           'AGRICULTURE': 1,
#                           'Now': 1,
#                           'Demand': 2,
#                           'High': 3,
#                           'Made': 1,
#                           'Side': 3,
#                           'CURRENT': 3,
#                           'direct': 1,
#                           'senior': 1,
#                           '0': 1,
#                           'Rep': 1,
#                           'Fibre': 1,
#                           'CORP': 1,
#                           'Reliance': 1,
#                           'FHL': 3,
#                           'automakers': 1,
#                           'investors': 1,
#                           'tallow': 1,
# ...
#                           'from': 7,
#                           'of': 5,
#                           'deficit': 1}),
#              ('baht',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'the': 1,
#                           'January': 2,
#                           'February': 2,
#                           '1986': 1}),
#              ('first',
#               'quarter'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'of': 80,
#                           'due': 3,
#                           'exports': 2,
#                           'against': 1,
#                           ',': 47,
#                           'average': 3,
#                           'earnings': 40,
#                           '1986': 12,
#                           '.': 47,
#                           'benefitted': 1,
#                           'loss': 8,
#                           'net': 20,
#                           ')."': 1,
#                           'resulted': 1,
#                           'results': 22,
#                           '1987': 16,
#                           'from': 6,
#                           'operating': 7,
#                           'last': 3,
#                           'could': 1,
#                           'and': 11,
#                           'should': 1,
#                           'record': 1,
#                           'rose': 1,
#                           'just': 1,
#                           'sales': 4,
#                           'to': 8,
#                           'in': 6,
#                           'was': 4,
#                           'profits': 4,
#                           'will': 6,
#                           'met': 1,
#                           'cocoa': 1,
#                           'the': 4,
#                           'shipments': 3,
#                           'profit': 4,
#                           'worldwide': 1,
#                           'ended': 17,
#                           'a': 2,
#                           'estimates': 1,
#                           'production': 2,
#                           'were': 3,
#                           'compared': 5,
#                           'fell': 1,
#                           'had': 1,
#                           'allowed': 1,
#                           'downturn': 1,
#                           'growth': 6,
#                           'figures': 1,
#                           'when': 1,
#                           'non': 1,
#                           'includes': 1,
#                           'charge': 2,
#                           'be': 1,
#                           'ending': 3,
#                           'since': 2,
#                           'reduction': 1,
#                           'revenues': 2,
#                           'GNP': 8,
#                           'tomorrow': 1,
#                           'fiscal': 5,
#                           'pig': 1,
#                           'international': 1,
#                           '(': 1,
#                           'levels': 1,
#                           'is': 3,
#                           ',"': 2,
#                           'labor': 1,
#                           'U': 2,
#                           'by': 2,
#                           'with': 1,
#                           'provision': 1,
#                           'total': 1,
#                           'but': 1,
#                           'proved': 1,
#                           'amount': 1,
#                           'are': 1,
#                           'spending': 1,
#                           'real': 2,
#                           'Cash': 1,
#                           '1985': 1,
#                           'gain': 1,
#                           'output': 1,
#                           "'": 1,
#                           'report': 1,
#                           'this': 1,
#                           '1988': 1}),
#              ('quarter',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'1987': 53,
#                           '1986': 63,
#                           'last': 9,
#                           'earnings': 1,
#                           '151': 1,
#                           'of': 1,
#                           'this': 13,
#                           '169': 1,
#                           'the': 13,
#                           '1988': 2,
#                           'operations': 1,
#                           'an': 1,
#                           'that': 1,
#                           '1985': 11,
#                           'fiscal': 8,
#                           'seven': 1,
#                           'a': 5,
#                           '175': 1,
#                           '14': 1,
#                           'calendar': 1,
#                           'about': 1,
#                           'which': 1,
#                           'its': 2,
#                           'M': 1,
#                           '12': 1,
#                           '1983': 1,
#                           '17': 1,
#                           '1': 1,
#                           'U': 1,
#                           'Uganda': 1,
#                           'French': 1,
#                           '1984': 1,
#                           'our': 1}),
#              ('of',
#               '1987'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'from': 14,
#                           'against': 3,
#                           ',': 41,
#                           '.': 58,
#                           'to': 7,
#                           '."': 2,
#                           'totalled': 2,
#                           'are': 3,
#                           'stands': 1,
#                           'there': 1,
#                           'first': 1,
#                           'will': 3,
#                           'and': 13,
#                           'after': 2,
#                           'of': 2,
#                           'widened': 2,
#                           'compared': 3,
#                           'were': 4,
#                           'has': 1,
#                           'as': 1,
#                           'was': 3,
#                           'that': 1,
#                           'had': 1,
#                           'may': 1,
#                           'it': 3,
#                           'U': 1,
#                           ',"': 3,
#                           'would': 3,
#                           'developed': 1,
#                           'at': 1,
#                           'is': 2,
#                           'compare': 1,
#                           'subject': 1,
#                           'crop': 1,
#                           'because': 1,
#                           'over': 1,
#                           'nominal': 1,
#                           'spending': 1,
#                           '/': 1,
#                           'does': 1,
#                           '",': 1,
#                           'together': 1}),
#              ('1987',
#               'from'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'2': 10,
#                           '1': 4,
#                           '53': 1,
#                           '18': 1,
#                           'a': 4,
#                           'fiscal': 1,
#                           '248': 1,
#                           '3': 3,
#                           '19': 1,
#                           'about': 2,
#                           'an': 2,
#                           '41': 1,
#                           '13': 1,
#                           '123': 1,
#                           '85': 1,
#                           '6': 1,
#                           'the': 2,
#                           '870': 1,
#                           '54': 1,
#                           '515': 1,
#                           'last': 1,
#                           '12': 1,
#                           '727': 1,
#                           'more': 1,
#                           'zero': 1,
#                           '15': 1,
#                           '50': 1,
#                           '233': 1,
#                           '374': 1}),
#              ('from',
#               '2'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'.': 115,
#                           ',': 18,
#                           '-': 1}),
#              ('billion',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'year': 65,
#                           'month': 7}),
#              ('a',
#               'year'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'ago': 226,
#                           'for': 17,
#                           '.': 59,
#                           'earlier': 313,
#                           'ending': 2,
#                           'before': 31,
#                           'of': 6,
#                           'later': 2,
#                           '-': 45,
#                           ',': 32,
#                           'through': 2,
#                           'to': 3,
#                           'from': 15,
#                           'in': 11,
#                           'but': 1,
#                           'production': 1,
#                           'until': 3,
#                           'ahead': 1,
#                           'earlie': 1,
#                           'previously': 1,
#                           'out': 1,
#                           'at': 4,
#                           'sugar': 2,
#                           'and': 7,
#                           'into': 2,
#                           'just': 1,
#                           'by': 3,
#                           "'": 1,
#                           'swap': 1,
#                           'following': 1,
#                           'capacity': 1,
#                           ',"': 1,
#                           'over': 7,
#                           'against': 1,
#                           'because': 1,
#                           'would': 2,
#                           'the': 1,
#                           'between': 2,
#                           'on': 3,
#                           'now': 1,
#                           '."': 1,
#                           'or': 3,
#                           '"': 1,
#                           'industry': 1,
#                           'while': 1,
#                           'this': 1,
#                           'after': 1,
#                           'since': 1,
#                           'up': 1,
#                           'worth': 1,
#                           'when': 1,
#                           'plant': 1}),
#              ('year',
#               'ago'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {',': 58,
#                           '.': 132,
#                           'as': 4,
#                           'period': 13,
#                           'quarter': 7,
#                           'first': 2,
#                           'loss': 1,
#                           'per': 2,
#                           'when': 5,
#                           'after': 4,
#                           'and': 10,
#                           'we': 1,
#                           'the': 3,
#                           'in': 2,
#                           'Washington': 1,
#                           '93': 2,
#                           'due': 1,
#                           'WestLB': 1,
#                           'while': 1,
#                           'month': 1,
#                           'second': 1,
#                           '540': 1,
#                           ',"': 3,
#                           'figure': 2,
#                           'but': 1,
#                           'had': 1,
#                           'level': 3,
#                           'at': 1,
#                           'qtr': 1,
#                           'to': 3,
#                           'before': 1,
#                           'extraordinary': 2,
#                           '-': 1,
#                           'net': 1,
#                           'adjusted': 1,
#                           '(': 2,
#                           'he': 1}),
#              ('ago',
#               ','): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'the': 28,
#                           'at': 1,
#                           'caused': 1,
#                           'mainly': 1,
#                           'Canadian': 1,
#                           'while': 4,
#                           'he': 2,
#                           'Abbott': 1,
#                           'USDA': 1,
#                           'widescale': 1,
#                           'bankers': 3,
#                           'and': 10,
#                           'but': 8,
#                           'Yates': 1,
#                           'have': 1,
#                           'an': 1,
#                           'probably': 1,
#                           'had': 1,
#                           'said': 2,
#                           'has': 2,
#                           'thanks': 1,
#                           '24': 1,
#                           'because': 2,
#                           'Chirac': 1,
#                           'is': 3,
#                           'maybe': 1,
#                           'these': 1,
#                           'we': 1,
#                           'official': 1,
#                           'only': 1,
#                           'it': 3,
#                           'which': 1,
#                           'money': 1,
#                           'remains': 1,
#                           'Huges': 1,
#                           'I': 1,
#                           'marked': 1,
#                           'K': 1,
#                           'a': 1,
#                           'before': 1,
#                           'industry': 1,
#                           'world': 1,
#                           'Chairman': 1,
#                           'ended': 1,
#                           'according': 1,
#                           'reported': 1,
#                           'Hughes': 1,
#                           'in': 1,
#                           'Utilicorp': 1}),
#              ('the',
#               'Business'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'Economics': 1,
#                           'Administration': 2,
#                           'Appeal': 1}),
#              ('Business',
#               'Economics'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'Department': 1}),
#              ('Economics',
#               'Department'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'said': 1,
#                           ',': 1}),
#              ('Department',
#               'said'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'.': 146,
#                           'private': 6,
#                           'the': 7,
#                           'these': 1,
#                           'it': 14,
#                           'on': 2,
#                           'this': 1,
#                           'just': 1,
#                           'cumulative': 1,
#                           'an': 2,
#                           'its': 1,
#                           'Thailand': 1,
#                           'Turkey': 1,
#                           'Florida': 1,
#                           'deficiency': 1,
#                           'in': 1,
#                           'non': 1,
#                           'that': 1,
#                           'all': 1,
#                           'imports': 1,
#                           'current': 1,
#                           'wage': 1,
#                           ',': 1,
#                           'two': 2,
#                           'Friday': 1,
#                           'exceptionally': 2}),
#              ('said',
#               'Janunary'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'/': 1}),
#              ('Janunary',
#               '/'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'March': 1}),
#              ('/',
#               'March'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'imports': 1,
#                           '1987': 1,
#                           ')': 2,
#                           '13': 1,
#                           'quarter': 3,
#                           '25': 1,
#                           'from': 2,
#                           ',': 1,
#                           'period': 1}),
#              ('March',
#               'imports'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'rose': 1}),
#              ...})

# %%
sorted(dict(model["world", "markets"]).items(), key=lambda x:x[1], reverse=True)
# Out:
# [('and', 16),
#  (',', 13),
#  ('.', 10),
#  ('at', 5),
#  ('helped', 1),
#  ('while', 1),
#  ('continues', 1),
#  ('in', 1),
#  ('."', 1),
#  ('has', 1)]

# %%
for w1_2 in model:
  total_count = sum(model[w1_2].values())
  for w3 in model[w1_2]:
    model[w1_2][w3] /= total_count
print(dict(model))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
